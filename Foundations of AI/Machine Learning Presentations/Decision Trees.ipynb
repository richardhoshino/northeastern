# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

data= datasets.load_iris()
target=data.target
df=data.data
dep = 2
type = 'gini'
#type = 'entropy'

# %%
# Create a test and train set
X_train, X_test, Y_train, Y_test = train_test_split(df, target, test_size=0.20)

# %%
dtree = DecisionTreeClassifier(max_depth = dep, criterion = type)
dtree.fit(X_train, Y_train)
fig = plt.figure(figsize=(25,20))
tree.plot_tree(dtree, 
                   feature_names=data.feature_names,  
                   class_names=data.target_names,
                   filled=True)
# Out:
# [Text(558.0, 906.0, 'petal width (cm) <= 0.75\ngini = 0.666\nsamples = 120\nvalue = [38, 40, 42]\nclass = virginica'),
#  Text(279.0, 543.6, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]\nclass = setosa'),
#  Text(837.0, 543.6, 'petal length (cm) <= 4.75\ngini = 0.5\nsamples = 82\nvalue = [0, 40, 42]\nclass = virginica'),
#  Text(558.0, 181.19999999999993, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]\nclass = versicolor'),
#  Text(1116.0, 181.19999999999993, 'gini = 0.124\nsamples = 45\nvalue = [0, 3, 42]\nclass = virginica')]

# %%
print(len(df))
print(data.feature_names)
print(df[149])
print(dtree.predict([df[149]]))
print(data.target_names[dtree.predict([df[149]])])
# Out:
# 150
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# [5.9 3.  5.1 1.8]
# [2]
# ['virginica']

# %%
score = dtree.score(X_test, Y_test)
score
# Out:
# 0.8666666666666667
